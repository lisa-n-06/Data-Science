# %%
import numpy as np
a=np.array([12,26,39,44,20,22])
print(a[0])
print(a[5])
a.shape
# Out:
# 12
# 22
# (6,)

# %%
a1=np.array([[31,32,33],[34,35,36]])
print(a1[1,2])
print(a1[0,:])
# Out:
# 36
# [31 32 33]

# %%
a2=np.arange(1,11)
a2[2:7]
# Out:
# array([3, 4, 5, 6, 7])

# %%
#broadcast

b=np.array([9,4,8])

ad=b+a1
print(ad)
# Out:
# [[40 36 41]
#  [43 39 44]]

# %%
#unique value
np.unique(a1)
# Out:
# array([31, 32, 33, 34, 35, 36])

# %%
#vectorization
a3=(a2*5)
a3
# Out:
# array([ 5, 10, 15, 20, 25, 30, 35, 40, 45, 50])

# %%
import pandas as pd
d=pd.DataFrame({"Name":["lisa","Bosha","ajay"],"Mark":[9,12,89],"Grade":["C","B","A"]})
d
# Out:
#     Name  Mark Grade
# 0   lisa     9     C
# 1  Bosha    12     B
# 2   ajay    89     A

# %%
#greater than 50 mark
d["Mark"]>50
# Out:
# 0    False
# 1    False
# 2     True
# Name: Mark, dtype: bool

# %%
d["Mark"].mean()
# Out:
# np.float64(36.666666666666664)

# %%
#rename
d['Mark'].rename("Rank")
# Out:
# 0     9
# 1    12
# 2    89
# Name: Rank, dtype: int64

# %%
#line chart
import matplotlib.pyplot as plt
x=[15,20,40,85]
y=[100,200,300,400]
plt.plot(x,y)
plt.show()

# %%
b1=["book","pen","pencil","note"]
b2=[150,250,350,450]

plt.bar(b1,b2)
plt.show()

# %%
#mean
av=np.array([1,29,34,56,77,12])
print(av.mean())
# Out:
# 34.833333333333336

# %%
sales=[1,29,34,56,77,12]
np.median(sales)
# Out:
# np.float64(31.5)

# %%
#mode
from scipy import stats
s=stats.mode(sales)
s
# Out:
# ModeResult(mode=np.int64(1), count=np.int64(1))

# %%
s1=np.std(sales)
s1
# Out:
# np.float64(25.582654714126566)
