# %%
import numpy as np
a=np.random.rand(3,3)
a
# Out:
# array([[0.05589427, 0.56594676, 0.96285257],
#        [0.5711861 , 0.84851339, 0.44426509],
#        [0.07955144, 0.88052495, 0.86909675]])

# %%
b=np.arange(2,8).reshape(2,3)
b
# Out:
# array([[2, 3, 4],
#        [5, 6, 7]])

# %%
np.ndim(b)
# Out:
# 2

# %%
#mathematical functions

np.sum(b)
# Out:
# np.int64(27)

# %%
a=np.array([[1,5,9],[8,2,1]])
np.ndim(a)
# Out:
# 2

# %%
np.random.randint(15,25,5)
# Out:
# array([23, 19, 16, 23, 22], dtype=int32)

# %%
np.random.randint(3,5,20)
# Out:
# array([4, 3, 4, 4, 4, 4, 4, 3, 4, 3, 4, 3, 4, 4, 3, 4, 3, 4, 4, 4],
#       dtype=int32)

# %%
np.vstack( a)
# Out:
# array([[1, 5, 9],
#        [8, 2, 1]])

# %%
np.hstack(a)
# Out:
# array([1, 5, 9, 8, 2, 1])

# %%
np.random.normal(3,5,20)
# Out:
# array([ 2.54822674,  1.94371979,  2.14080456, 13.31171343, -8.47701769,
#         2.03140131,  3.01237126,  8.79801522,  5.87698693, -1.44630888,
#        -1.25971468, -5.32921732, -1.09277958,  1.37800751,  4.99938921,
#        -4.94811327, 13.00592868,  6.3463528 , -2.26603884, -2.1828882 ])

# %%
np.max(a)
# Out:
# np.int64(9)

# %%
np.min(a)
# Out:
# np.int64(1)

# %%
np.median(a)
# Out:
# np.float64(3.5)

# %%
np.log(a)
# Out:
# array([[0.        , 1.60943791, 2.19722458],
#        [2.07944154, 0.69314718, 0.        ]])

# %%
np.sqrt(a)
# Out:
# array([[1.        , 2.23606798, 3.        ],
#        [2.82842712, 1.41421356, 1.        ]])

# %%
a
# Out:
# array([[1, 5, 9],
#        [8, 2, 1]])

# %%
np.std(a)
# Out:
# np.float64(3.2489314482696545)

# %%
np.exp(a)
# Out:
# array([[2.71828183e+00, 1.48413159e+02, 8.10308393e+03],
#        [2.98095799e+03, 7.38905610e+00, 2.71828183e+00]])

# %%
f=np.array([3,5,6])
f[2]
# Out:
# np.int64(6)

# %%
a
# Out:
# array([[1, 5, 9],
#        [8, 2, 1]])

# %%
a
# Out:
# array([[1, 5, 9],
#        [8, 2, 1]])

# %%
b
# Out:
# array([[2, 3, 4],
#        [5, 6, 7]])

# %%
b[1,1]
# Out:
# np.int64(6)

# %%
c=np.array([[[1,2,3],[5,4,8]],[[11,34,45],[22,13,22]]])
c
# Out:
# array([[[ 1,  2,  3],
#         [ 5,  4,  8]],
#
#        [[11, 34, 45],
#         [22, 13, 22]]])

# %%
c[1,0:2,1:3]
# Out:
# array([[34, 45],
#        [13, 22]])

# %%
m=np.array([1,2,3])
d=np.array([[4],[5],[6]])
s=m+d
s
# Out:
# array([[5, 6, 7],
#        [6, 7, 8],
#        [7, 8, 9]])

# %%
s.flatten()
# Out:
# array([5, 6, 7, 6, 7, 8, 7, 8, 9])

# %%
s.ravel()
# Out:
# array([5, 6, 7, 6, 7, 8, 7, 8, 9])

# %%
import pandas as pd
d=pd.read_csv(r"C:\Users\Mohan\Downloads\pokemon.csv")
d
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
d.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
d.tail()
# Out:
#            abilities  against_bug  against_dark  against_dragon  \
# 796  ['Beast Boost']         0.25           1.0             0.5
# 797  ['Beast Boost']         1.00           1.0             0.5
# 798  ['Beast Boost']         2.00           0.5             2.0
# 799  ['Prism Armor']         2.00           2.0             1.0
# 800   ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 796               2.0            0.5            1.0           2.0
# 797               0.5            0.5            2.0           4.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 796             0.5            1.0  ...              NaN             797
# ...

# %%
d.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
d.columns[d.isna().any()]
# Out:
# Index(['height_m', 'percentage_male', 'type2', 'weight_kg'], dtype='object')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
#null value

d['height_m']=d["height_m"].fillna(d["height_m"].median())
d['height_m']
# Out:
# 0      0.7
# 1      1.0
# 2      2.0
# 3      0.6
# 4      1.1
#       ...
# 796    9.2
# 797    0.3
# 798    5.5
# 799    2.4
# 800    1.0
# Name: height_m, Length: 801, dtype: float64

# %%
d["height_m"].unique()
# Out:
# array([ 0.7,  1. ,  2. ,  0.6,  1.1,  1.7,  0.5,  1.6,  0.3,  1.5,  1.2,
#         3.5,  0.4,  0.8,  1.3,  0.9,  1.4,  1.9,  1.8,  8.8,  2.2,  6.5,
#         2.5,  2.1,  4. ,  2.3,  0.2,  9.2,  5.2,  3.8, 14.5,  2.7,  6.2,
#         4.5,  7. ,  2.4,  5.4,  4.2,  3.7,  3.2,  3.3,  0.1,  2.6,  2.8,
#         2.9,  3. ,  5.8,  5. ,  3.9,  3.4,  5.5])

# %%
d["type2"]=d["type2" ].fillna(d["type2" ].mode()[0])
d["type2"]
# Out:
# 0      poison
# 1      poison
# 2      poison
# 3      flying
# 4      flying
#         ...
# 796    flying
# 797     steel
# 798    dragon
# 799    flying
# 800     fairy
# Name: type2, Length: 801, dtype: object

# %%
d["type2"].unique()
# Out:
# array(['poison', 'flying', 'dark', 'electric', 'ice', 'ground', 'fairy',
#        'grass', 'fighting', 'psychic', 'steel', 'fire', 'rock', 'water',
#        'dragon', 'ghost', 'bug', 'normal'], dtype=object)
