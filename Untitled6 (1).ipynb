# %%
import pandas as pd
d=pd.read_csv("CC GENERAL.csv")
d
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
d1=d.head(2000)
d1
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 1995  C12058     3.031240           0.272727      37.65             37.65
# 1996  C12059   163.950974           0.777778    1014.21            264.42
# 1997  C12060  2926.920514           1.000000    1823.50           1686.00
# 1998  C12061  1502.444690           1.000000       0.00              0.00
# 1999  C12062    74.825456           1.000000     293.50             49.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
d1.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE', 'cluster'],
#       dtype='object')

# %%
d1.columns[d1.isna().any()]
# Out:
# Index([], dtype='object')

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           2000 non-null   object
#  1   BALANCE                           2000 non-null   float64
#  2   BALANCE_FREQUENCY                 2000 non-null   float64
#  3   PURCHASES                         2000 non-null   float64
#  4   ONEOFF_PURCHASES                  2000 non-null   float64
#  5   INSTALLMENTS_PURCHASES            2000 non-null   float64
#  6   CASH_ADVANCE                      2000 non-null   float64
#  7   PURCHASES_FREQUENCY               2000 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        2000 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  2000 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            2000 non-null   float64
# ...

# %%
d1[["CREDIT_LIMIT", "MINIMUM_PAYMENTS"]] = d1[["CREDIT_LIMIT", "MINIMUM_PAYMENTS"]].fillna(
    d1[["CREDIT_LIMIT", "MINIMUM_PAYMENTS"]].mean()
)
# Out:
# C:\Users\Mohan\AppData\Local\Temp\ipykernel_19384\4170468244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d1[["CREDIT_LIMIT", "MINIMUM_PAYMENTS"]] = d1[["CREDIT_LIMIT", "MINIMUM_PAYMENTS"]].fillna(

# %%
d1.columns[d1.isna().any()]
# Out:
# Index([], dtype='object')

# %%
x = d1[["BALANCE", "PURCHASES", "CREDIT_LIMIT"]].drop_duplicates()
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
s1=s.fit_transform(x)
s1
# Out:
# array([[-0.8281508 , -0.4285513 , -1.17134936],
#        [ 0.41408033, -0.45764887,  0.23543938],
#        [ 0.13616333, -0.22182747,  0.35267178],
#        ...,
#        [ 0.30581345,  0.09852936,  0.25888586],
#        [-0.25388634, -0.45764887, -1.03067048],
#        [-0.81482123, -0.36812964, -1.05411696]], shape=(2000, 3))

# %%
from sklearn.cluster import DBSCAN
db=DBSCAN()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

X = s1[["BALANCE","PURCHASES","CREDIT_LIMIT"]]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

db = DBSCAN(eps=0.5, min_samples=5)
l = db.fit_predict(X_scaled)

s1["cluster"] = l
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 4
#       1 from sklearn.preprocessing import StandardScaler
#       2 from sklearn.cluster import DBSCAN
# ----> 4 X = s1[["BALANCE","PURCHASES","CREDIT_LIMIT"]]
#       6 scaler = StandardScaler()
#       7 X_scaled = scaler.fit_transform(X)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
x
# Out:
#           BALANCE  PURCHASES  CREDIT_LIMIT  cluster
# 0       40.900749      95.40        1000.0        0
# 1     3202.467416       0.00        7000.0        0
# 2     2495.148862     773.17        7500.0        0
# 3     1666.670542    1499.00        7500.0        0
# 4      817.714335      16.00        1200.0        0
# ...           ...        ...           ...      ...
# 1995     3.031240      37.65        7500.0        0
# 1996   163.950974    1014.21        1500.0        0
# 1997  2926.920514    1823.50        7100.0        0
# 1998  1502.444690       0.00        1600.0        0
# 1999    74.825456     293.50        1500.0        0
#
# [2000 rows x 4 columns]
