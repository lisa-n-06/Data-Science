# %%
import pandas as pd
import  matplotlib.pyplot as plt
import numpy as np

# %%
d=pd.read_csv(r"C:\Users\Mohan\Downloads\netflix_titles.csv\netflix_titles.csv")
d
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
d.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
d.columns[d.isna().any()]
# Out:
# Index(['director', 'cast', 'country', 'date_added', 'rating', 'duration'], dtype='object')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
d['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
m=pd.get_dummies(d["rating"])
a=m.value_counts(normalize=True)
a
# Out:
# 66 min  74 min  84 min  G      NC-17  NR     PG     PG-13  R      TV-14  TV-G   TV-MA  TV-PG  TV-Y   TV-Y7  TV-Y7-FV  UR
# False   False   False   False  False  False  False  False  False  False  False  True   False  False  False  False     False    0.364142
#                                                                   True   False  False  False  False  False  False     False    0.245259
#                                                                   False  False  False  True   False  False  False     False    0.097990
#                                                            True   False  False  False  False  False  False  False     False    0.090723
#                                                     True   False  False  False  False  False  False  False  False     False    0.055638
#                                                     False  False  False  False  False  False  False  True   False     False    0.037924
# ...

# %%
d["rating"].value_counts(normalize=True)
# Out:
# rating
# TV-MA       0.364308
# TV-14       0.245371
# TV-PG       0.098035
# R           0.090765
# PG-13       0.055663
# TV-Y7       0.037942
# TV-Y        0.034874
# PG          0.032603
# TV-G        0.024991
# NR          0.009088
# G           0.004658
# TV-Y7-FV    0.000682
# NC-17       0.000341
# UR          0.000341
# 74 min      0.000114
# 84 min      0.000114
# 66 min      0.000114
# Name: proportion, dtype: float64

# %%
d.isnull().mean()
# Out:
# show_id         0.000000
# type            0.000000
# title           0.000000
# director        0.299080
# cast            0.093675
# country         0.094357
# date_added      0.001135
# release_year    0.000000
# rating          0.000454
# duration        0.000341
# listed_in       0.000000
# description     0.000000
# dtype: float64

# %%
d.isnull().mean().plot(kind="pie")
plt.legend()
plt.show()

# %%
d["date_added"]=pd.to_datetime(d["date_added"],format='%d-%m-%y')
d["date_added"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 d["date_added"]=pd.to_datetime(d["date_added"],format='%d-%m-%y')
#       2 d["date_added"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1069     if not cache_array.empty:
#    1070         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:249, in _maybe_cache(arg, format, cache, convert_listlike)
#     247 unique_dates = unique(arg)
#     248 if len(unique_dates) < len(arg):
# ...

# %%
d.groupby ("date_added")["title"].mean()

# %%
d[(d["title"])&(d["date_added"])]

# %%
d["date_added"].value_counts()

# %%
d["date_added"].value_counts().plot(kind="line")
plt.show()
