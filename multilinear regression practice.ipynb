# %%
import pandas as pd
d=pd.read_csv("fitness_tracker_dataset.csv")
d=d.head(1000)
d
# Out:
#      user_id        date  steps  calories_burned  distance_km  active_minutes  \
# 0        468  2023-01-01   4530          2543.02        16.10             613
# 1        879  2023-01-01  11613          1720.76         8.10             352
# 2        152  2023-01-01  27335          1706.35         3.57             236
# 3        311  2023-01-01  13459          2912.38         6.41            1329
# 4        759  2023-01-01  15378          3344.51        17.88              52
# ..       ...         ...    ...              ...          ...             ...
# 995      518  2023-01-01  19783          3257.98         4.22             964
# 996      801  2023-01-01   2982          2486.78         0.57             567
# 997      330  2023-01-01  29777          3009.25         4.88             167
# 998      390  2023-01-01   1618          1813.25        14.34            1315
# 999      658  2023-01-01  20875          2171.01        16.63             712
#
#      sleep_hours  heart_rate_avg workout_type weather_conditions location  \
# 0            1.5             176      Walking              Clear     Park
# 1            6.3             128      Cycling                Fog     Park
# 2            6.7             134         Yoga               Snow     Park
# 3           11.6             116     Swimming               Rain   Office
# 4            7.4              84     Swimming               Rain   Office
# ..           ...             ...          ...                ...      ...
# 995          8.7              68      Cycling               Snow     Home
# 996          0.9             149  Gym Workout              Clear     Park
# 997         12.0             173  Gym Workout               Snow    Other
# 998         10.1             168      Cycling              Clear     Park
# 999         10.4              90      Cycling               Rain   Office
#
#          mood
# 0       Tired
# 1       Happy
# 2     Neutral
# 3       Tired
# 4     Neutral
# ..        ...
# 995  Stressed
# 996  Stressed
# 997  Stressed
# 998   Neutral
# 999     Tired
#
# [1000 rows x 12 columns]

# %%
d1=d.select_dtypes(["int64","float64"])
d1
# Out:
#      user_id  steps  calories_burned  distance_km  active_minutes  \
# 0        468   4530          2543.02        16.10             613
# 1        879  11613          1720.76         8.10             352
# 2        152  27335          1706.35         3.57             236
# 3        311  13459          2912.38         6.41            1329
# 4        759  15378          3344.51        17.88              52
# ..       ...    ...              ...          ...             ...
# 995      518  19783          3257.98         4.22             964
# 996      801   2982          2486.78         0.57             567
# 997      330  29777          3009.25         4.88             167
# 998      390   1618          1813.25        14.34            1315
# 999      658  20875          2171.01        16.63             712
#
#      sleep_hours  heart_rate_avg
# 0            1.5             176
# 1            6.3             128
# 2            6.7             134
# 3           11.6             116
# 4            7.4              84
# ..           ...             ...
# 995          8.7              68
# 996          0.9             149
# 997         12.0             173
# 998         10.1             168
# 999         10.4              90
#
# [1000 rows x 7 columns]

# %%
d1.corr()
# Out:
#                   user_id     steps  calories_burned  distance_km  \
# user_id          1.000000 -0.019224        -0.004409     0.034479
# steps           -0.019224  1.000000        -0.024129    -0.020063
# calories_burned -0.004409 -0.024129         1.000000     0.010207
# distance_km      0.034479 -0.020063         0.010207     1.000000
# active_minutes  -0.014787 -0.014623        -0.034388    -0.020714
# sleep_hours      0.023234 -0.006250         0.014072    -0.022710
# heart_rate_avg   0.003641  0.016091        -0.020229     0.050204
#
#                  active_minutes  sleep_hours  heart_rate_avg
# user_id               -0.014787     0.023234        0.003641
# steps                 -0.014623    -0.006250        0.016091
# calories_burned       -0.034388     0.014072       -0.020229
# distance_km           -0.020714    -0.022710        0.050204
# active_minutes         1.000000     0.038941       -0.013041
# sleep_hours            0.038941     1.000000       -0.001399
# heart_rate_avg        -0.013041    -0.001399        1.000000

# %%
x=d1[["steps","distance_km"]]
y=d1["calories_burned"]

# %%
d1.kurt()
# Out:
# user_id           -1.136810
# steps             -1.111950
# calories_burned   -1.214293
# distance_km       -1.180295
# active_minutes    -1.199857
# sleep_hours       -1.237119
# heart_rate_avg    -1.245246
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)
x_train
# Out:
#      steps  distance_km
# 29    4798        11.42
# 535   1457         9.11
# 695  14384        18.82
# 557  22925        18.35
# 836  18522        18.44
# ..     ...          ...
# 106  15022         6.25
# 270   8838        19.99
# 860  11418        12.05
# 435  20566         9.41
# 102  16030        11.26
#
# [800 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
